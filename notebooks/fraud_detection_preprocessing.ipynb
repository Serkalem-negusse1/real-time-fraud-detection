# %% [markdown]
# # Fraud detection preprocessing

# %%
import sys 
sys.path.append('E:/Git_repo/real-time-fraud-detection/scripts')

# %%
# Import necessary functions from the script
from fraud_detection_preprocessing import preprocess_and_save, plot_fraud_vs_non_fraud, plot_transaction_value_distribution, plot_log_transformed_transaction_value, plot_outlier_detection, plot_feature_correlation_heatmap, plot_pairwise_correlation, plot_transaction_by_class, plot_geographical_distribution, plot_fraud_trends_over_time, plot_transaction_amount_by_country, check_multicollinearity
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Path to the data
fraud_data_path = "E:/data/Data08&9/Fraud_Data.csv"
ip_data_path = "E:/data/Data08&9/IpAddress_to_Country.csv"
output_path = "E:/Git_repo/real-time-fraud-detection/data/Processed_Fraud_Data.csv"

# %%
# Preprocess data (reuse the preprocessing steps from the script) 
fraud_df = preprocess_and_save(fraud_data_path, ip_data_path, output_path)
# Out:
# E:\Git_repo/real-time-fraud-detection/scripts\fraud_detection_preprocessing.py:22: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   fraud_df = fraud_df.fillna(method='ffill')  # You can change 'ffill' to 'bfill' or a specific value

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# Fraud vs Non-Fraud Transactions
plot_fraud_vs_non_fraud(fraud_df)

# %%
# Transaction Value Distribution
plot_transaction_value_distribution(fraud_df)

# %%
# Log Transformed Transaction Value Distribution
plot_log_transformed_transaction_value(fraud_df)

# %%
# Outlier Detection in Transaction Amounts
plot_outlier_detection(fraud_df)

# %%
# Feature Correlation Heatmap
plot_feature_correlation_heatmap(fraud_df)

# %%
# Pairwise Correlation
plot_pairwise_correlation(fraud_df)

# %%
# Transaction Amount by Fraud Class
plot_transaction_by_class(fraud_df)

# %%
# Geographical Fraud Distribution by Region
plot_geographical_distribution(fraud_df)

# %%
# Fraud Trends Over Time
plot_fraud_trends_over_time(fraud_df)

# %%
# Transaction Amount by Country
plot_transaction_amount_by_country(fraud_df)

# %%
# Multicollinearity Check (VIF)
check_multicollinearity(fraud_df)
print(vif_data)
# Out:
# Variance Inflation Factors (VIF):
#           feature        VIF
# 0           const  12.823114
# 1  purchase_value   1.000031
# 2     signup_hour   1.002308
# 3   purchase_hour   1.002316
# 4      signup_day   1.003473
# 5    purchase_day   1.003472

# %% [markdown]
# ### *************************************************
